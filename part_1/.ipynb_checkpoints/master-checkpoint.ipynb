# %% [markdown]
# # Using Collaborative Filtering to Recommend Alternative Movies
#
# ## Case Study
# The customer service team at Netflix has started to receive user complaints about Netflix having a limited catalog of movies. In response, the product team has decided that they want to suggest similar movies as a consolation to users that can't find their desired movie. The product team has asked their top two data scientist, Debbie and Juan Carlos, to create an algorithm that allows a user to receive suggested movies when their searched for movie is not available.
#
#
# ## Stakeholders
# 1. Product Team: This team has requested the ability to provide a user with suggested movies when the user is not able to find the specific movie they want to watch.
# 2. Customer Service Team: This team expects that the new feature will reduce the number of user complains about the movies not being available on their library.
#
# ## Success Metrics
# * The number of user complaints related to a movie not being available should show statistically significant decreases after the feature is implemented.
# * The number of people that watch a recommended movie should increase while the number of user complaints decreases.

# %%
# All the following libraries mush be imported
import numpy as np
from numpy.linalg import inv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
import itertools
from timeit import default_timer as timer

from surprise import SVD
from surprise import KNNWithMeans
from surprise import Reader, Dataset
from surprise import evaluate, print_perf, GridSearch
from surprise import accuracy

# %%
if os.getcwd().split('/')[-1] == 'Personalization Project':
    print('Congratulations you are in the correct working direcotry')
else:
    print('Please reopen the notebook from the \'Personalization Project\' directory \
    using the command listed in the README')
# Out:
# Congratulations you are in the correct working direcotry

# %% [markdown]
# First, we will build a neighborhood user-based model. Put simply, this means that our recommendations for a given user "Bob" will be based on the ratings of people who have similar taste in movies as Bob. This set of people are Bob's neighbors, and we will use the mean neighbor ratings for a given movie X to estimate what rating Bob will give movie X. If Bob's predicted rating is high then this is a movie we will recommend to Bob because we think he would like it.

# %% [markdown]
# Let's import our data. Before we do any model building, we need to think carefully about how we split the data. We will set aside a portion of the data (say, 20%) to be our "test" data. This test data will be untouched while we build our model, and we'll only use it at the end when we want to see how well our model did at predicting on fresh data. As for the other 80% of the dataset, we can split this further into "train" and "tune" data. We will train our model on the training dataset, check accuracy on the tuning dataset, then we can iteratively improve the model accuracy through hyper parameter optimization.

# %%
files_dir = os.path.expanduser('./data/')
reader = Reader(line_format='user item rating', sep=',')

train_file = files_dir + 'ratings_train.csv'
test_file = files_dir + 'ratings_test.csv'

folds_files = [(train_file, test_file)]
data = Dataset.load_from_folds(folds_files, reader=reader)

# %% [markdown]
# We have selected KNN with means for our first algorithm. This is a k nearest neighbors user-based model that takes into account each user's mean rating. So overly pessimistic or optimistic people will not bias the recommendations.

# %% [markdown]
# <img src="img/kNN_mean_formula.png", width = 400, height=400>

# %%
sim_options = {'name': 'pearson',
               'user_based': True  # compute  similarities between users
               }

algo = KNNWithMeans(sim_options=sim_options)

# %%
for trainset, testset in data.folds():

    # train and test algorithm.
    algo.train(trainset)
    predictions = algo.test(testset)
    accuracy.rmse(predictions, verbose=True)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9145

# %% [markdown]
# We are using RMSE, or root mean squared error to measure accuracy. RMSE penalizes outliers, which makes sense for our use case, which is to present alternative movies when a movie is unavailable in our catalog. Optimizing for RMSE would prevent our model from making outlier suggestions (suggesting to a user a movie that they would've rated a 1). Since the user might be upset already that their desired movie isn't available, we don't want to anger them further by making a wildly off-base recommendation.

# %% [markdown]
# We should also consider coverage, or in our case, the percentage of users who receive an adequate number of recommendations. If we decide to show each user their top 10 recommended movies, what percentage of users will actually receive 10 recommendations?

# %%
from collections import defaultdict

def get_top_n(predictions, n=10):

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

top_n = get_top_n(predictions, n=10)

users = []
num_recs = []

for uid, user_ratings in top_n.items():
    users.append(uid)
    num_recs.append(len(user_ratings))

# %%
coverage = pd.DataFrame(list(zip(users, num_recs)),
              columns=['uid','num_recs'])
coverage['under10'] = np.where(coverage['num_recs']<10, 'yes', 'no')
pd.value_counts(coverage['under10'].values, sort=False)
# Out:
# yes    234
# no     436
# dtype: int64

# %% [markdown]
# 65% of our users will receive more than 10 recommended movies, so this is our user coverage. Obviously this number will improve if we decide to show fewer than 10 recommended movies. This coverage percentage doesn't seem very high, I think we can do better on this.

# %% [markdown]
# ## Hyper parameter optimization

# %% [markdown]
# Now that we've established a baseline, let's do some hyper parameter optimization to make our model even better. We will split our training data into 3 folds. For KNN with means, the main parameters we can tweak are k, and min-k. k is the maximum number of neighbors to take into account. min-k is the minimum number of neighbors needed to make a prediction. In our earlier model, the defaults were set to k=40, min_k = 1.

# %%
train_data = Dataset.load_from_file('./data/ratings_train.csv', reader=reader)

#split into folds
train_data.split(n_folds=3)

#generating K's to iterate through, starting at 30 and ending at 100 in interval of 10.
klist = []
for i in range(30,80,10):
    klist.append(i)
    
param_grid = {'k': klist,
              'min_k': [1,2,3,4,5]}

grid_search = GridSearch(KNNWithMeans, param_grid, measures=['RMSE'])

grid_search.evaluate(train_data)

results_df = pd.DataFrame.from_dict(grid_search.cv_results)
# Out:
# [{'k': 30, 'min_k': 1}, {'k': 30, 'min_k': 2}, {'k': 30, 'min_k': 3}, {'k': 30, 'min_k': 4}, {'k': 30, 'min_k': 5}, {'k': 40, 'min_k': 1}, {'k': 40, 'min_k': 2}, {'k': 40, 'min_k': 3}, {'k': 40, 'min_k': 4}, {'k': 40, 'min_k': 5}, {'k': 50, 'min_k': 1}, {'k': 50, 'min_k': 2}, {'k': 50, 'min_k': 3}, {'k': 50, 'min_k': 4}, {'k': 50, 'min_k': 5}, {'k': 60, 'min_k': 1}, {'k': 60, 'min_k': 2}, {'k': 60, 'min_k': 3}, {'k': 60, 'min_k': 4}, {'k': 60, 'min_k': 5}, {'k': 70, 'min_k': 1}, {'k': 70, 'min_k': 2}, {'k': 70, 'min_k': 3}, {'k': 70, 'min_k': 4}, {'k': 70, 'min_k': 5}]
# ------------
# Parameters combination 1 of 25
# params:  {'k': 30, 'min_k': 1}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9408
# ------------
# ------------
# Parameters combination 2 of 25
# params:  {'k': 30, 'min_k': 2}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9320
# ------------
# ------------
# Parameters combination 3 of 25
# params:  {'k': 30, 'min_k': 3}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9298
# ------------
# ------------
# Parameters combination 4 of 25
# params:  {'k': 30, 'min_k': 4}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9289
# ------------
# ------------
# Parameters combination 5 of 25
# params:  {'k': 30, 'min_k': 5}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9302
# ------------
# ------------
# Parameters combination 6 of 25
# params:  {'k': 40, 'min_k': 1}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9403
# ------------
# ------------
# Parameters combination 7 of 25
# params:  {'k': 40, 'min_k': 2}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9315
# ------------
# ------------
# Parameters combination 8 of 25
# params:  {'k': 40, 'min_k': 3}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9293
# ------------
# ------------
# Parameters combination 9 of 25
# params:  {'k': 40, 'min_k': 4}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9284
# ------------
# ------------
# Parameters combination 10 of 25
# params:  {'k': 40, 'min_k': 5}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9297
# ------------
# ------------
# Parameters combination 11 of 25
# params:  {'k': 50, 'min_k': 1}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9404
# ------------
# ------------
# Parameters combination 12 of 25
# params:  {'k': 50, 'min_k': 2}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9316
# ------------
# ------------
# Parameters combination 13 of 25
# params:  {'k': 50, 'min_k': 3}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9294
# ------------
# ------------
# Parameters combination 14 of 25
# params:  {'k': 50, 'min_k': 4}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9285
# ------------
# ------------
# Parameters combination 15 of 25
# params:  {'k': 50, 'min_k': 5}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9298
# ------------
# ------------
# Parameters combination 16 of 25
# params:  {'k': 60, 'min_k': 1}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9405
# ------------
# ------------
# Parameters combination 17 of 25
# params:  {'k': 60, 'min_k': 2}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9317
# ------------
# ------------
# Parameters combination 18 of 25
# params:  {'k': 60, 'min_k': 3}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9296
# ------------
# ------------
# Parameters combination 19 of 25
# params:  {'k': 60, 'min_k': 4}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9287
# ------------
# ------------
# Parameters combination 20 of 25
# params:  {'k': 60, 'min_k': 5}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9300
# ------------
# ------------
# Parameters combination 21 of 25
# params:  {'k': 70, 'min_k': 1}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9406
# ------------
# ------------
# Parameters combination 22 of 25
# params:  {'k': 70, 'min_k': 2}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9318
# ------------
# ------------
# Parameters combination 23 of 25
# params:  {'k': 70, 'min_k': 3}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9297
# ------------
# ------------
# Parameters combination 24 of 25
# params:  {'k': 70, 'min_k': 4}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9288
# ------------
# ------------
# Parameters combination 25 of 25
# params:  {'k': 70, 'min_k': 5}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9301
# ------------

# %%
#plot the results of our hyper parameter optimization
results_df.plot(x=['params'], y=['RMSE'])
plt.show()

# %% [markdown]
# From left to right on the graph above, different pairs of k and min-k are plotted to show how the RMSE is changing. Starting at the lowest k value and lowest min-k (k=30, min-k=1) on the left, the RMSE is relatively high. The number of neighbors being considered is small, and a user only needs to have 1 neighbor to calculate a prediction. This means the predictions will be unstable, since when there is only 1 neighbor, the user will take on the rating from that 1 neighbor. As min-k cycles from 1 to 5, the RMSE drops at min-k = 4. We confirm by finding the argmin for the best k and min-k below.

# %%
#find the best parameters
# best RMSE score
print(grid_search.best_score['RMSE'])

# combination of parameters that gave the best RMSE score
print(grid_search.best_params['RMSE'])
# Out:
# 0.928390239808
# {'k': 40, 'min_k': 4}

# %% [markdown]
# Check accuracy on test set using the best parameters found from grid search:

# %%
sim_options = {'name': 'pearson',
               'user_based': True  # compute  similarities between users
               }

algo = KNNWithMeans(k=40, min_k=4, sim_options=sim_options)

for trainset, testset in data.folds():

    # train and test algorithm.
    algo.train(trainset)
    predictions = algo.test(testset)
    accuracy.rmse(predictions, verbose=True)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9595
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9599
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9647

# %% [markdown]
# ## How does the model scale from small data to larger data?

# %%
from timeit import default_timer as timer

data = Dataset.load_builtin('ml-100k')
raw_ratings = data.raw_ratings

samples = []
acc = []
timing = []
for i in range(1,10,1):
    start = timer()
    threshold = int((i/10) * len(raw_ratings))
    A_raw_ratings = raw_ratings[:threshold]
    B_raw_ratings = raw_ratings[threshold:]
    
    samples.append(threshold)

    data.raw_ratings = A_raw_ratings  # data is now the set A
    data.split(n_folds=3)

    sim_options = {'name': 'pearson',
                   'user_based': True  # compute  similarities between users
                   }

    #using best parameters from grid search
    algo = KNNWithMeans(k=40, min_k=4, sim_options=sim_options)

    # retrain on the whole set A
    trainset = data.build_full_trainset()
    algo.train(trainset)
    end = timer()
    timing.append(end - start) 

    # Compute unbiased accuracy on B
    testset = data.construct_testset(B_raw_ratings)  # testset is now the set B
    predictions = algo.test(testset)
#     accuracy.rmse(predictions)
    acc.append(accuracy.rmse(predictions))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.1015
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0701
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0578
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0402
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0321
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9947
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9559
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9460
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9433

# %%
sample_acc = pd.DataFrame(list(zip(samples, acc, timing)),
              columns=['sample_size','test_RMSE', 'runtime'])

sample_acc.plot(x=['sample_size'], y=['test_RMSE'])
sample_acc.plot(x=['sample_size'], y=['runtime'])

plt.show()

# %% [markdown]
# As you can see in the graphs above, as the size of the data being sampled gets larger, error gets lower (accuracy gets better). This makes sense because the model is being trained on a larger base of data and is more stable (central limit theorem). Accordingly, the runtime also increases because the model is finding neighbors for more users as the data gets larger.

# %% [markdown]
# ## So how did we do with this first model?
#
# blah blah

# %% [markdown]
# # JC's CODE

# %% [raw]
# # HIDE ME as RAW
# #%% Set working directory to Personalizatin Project folder
# # REMOVE THIS FROM THE NOTEBOOK
# git_directory = '/Users/juancoronel/Google Drive/home_work/Columbia_Classes/\
# 2017_personalization/Personalization Project'
# os.chdir(git_directory)

# %% [raw]
# # HIDE ME as RAW
# #%%  Explore the movies file (DO NOT RUN THIS AGAIN)
# '''
# movies = pd.read_csv('./ml-latest-small/movies.csv')
# temp = movies[['movieId','title']].reset_index()
# movies = temp.rename(columns={'index':'new_movieId'})
# movies.new_movieId = movies.new_movieId +1
# movies.to_csv('./data/movies_newid', index=False)
# '''

# %% [markdown]
# ### Import Data
# Note that a new movie ID has been created for this algorithm in order to reduce the dimmension of the matrix and maintian a relationship between the column number and the movie ID

# %%
# import the movie names data set

movies = pd.read_csv('./data/movies_newid')
movies.head()
# Out:
#    new_movieId  movieId                               title
# 0            1        1                    Toy Story (1995)
# 1            2        2                      Jumanji (1995)
# 2            3        3             Grumpier Old Men (1995)
# 3            4        4            Waiting to Exhale (1995)
# 4            5        5  Father of the Bride Part II (1995)

# %%
# Import ratings

rawdata = pd.read_csv('./data/ratings.csv')
# replace the movie ID with the new movie id
rawdata = pd.merge(rawdata,movies[['new_movieId','movieId']],how='left',left_on='movieId',right_on='movieId')
rawdata = rawdata[['userId','new_movieId','rating']].rename(columns={'userId':'user_id', 'new_movieId':'movie_id'})
ratings_full = rawdata

# %% [raw]
# #%% !!!!(DO WE WANT TO DO THIS) Normalize ratings by substracting the each users mean rating respectively
#
# # The line below is not used but it is an alternative way of substractivn the mean
# #rawdata['rating'] = rawdata['rating']-rawdata['rating'].mean()
#
# temp =rawdata.groupby('user_id')['rating'].mean()
#
# print('Before \n', rawdata.tail(), '\n')
# rawdata['rating'] = rawdata.apply(lambda x: x['rating']-temp[x['user_id']], axis=1)
# print('After \n', rawdata.tail(), '\n')

# %%
# We split the data into a training set and a test set
# CAUTION: this code may have problems if the random test set contains all the ratings of the last movie. This is highly unlikely.

rawdata_train, rawdata_test = train_test_split(rawdata,test_size=0.2)
#rawdata = pd.read_csv('./data/ratings_train.csv')
print(rawdata_train.shape, ' Train Data')
print(rawdata_test.shape, ' Test Data')
rawdata_train.head()
# Out:
# (80003, 3)  Train Data
# (20001, 3)  Test Data
#        user_id  movie_id  rating
# 24291      176      1121     3.0
# 31246      224        10     3.0
# 96075      639       268     4.0
# 81777      558      2552     4.0
# 75750      527       448     1.0

# %% [markdown]
# ### SCALING TEST: Test the time of execution with different data sparcities.

# %%
# This cell runs the model with datasets of different sizes to test the execution time

#Parameters
ds= 10 # The number of factors
sigmas = 1 # The learning rate
lams = 5 # The regularization parameter
iterations = 50
data_sizes = [.9,.8, .7,.6, .5, .4, .3,.2,.1]

durations = pd.DataFrame(np.zeros((len(data_sizes), 2)), columns=['percent_of_data', 'Time in seconds'])
# MODEL

# Now we run the model for different sizes size data set
for row, keep in enumerate(data_sizes):
    
    # We now create the appropriate matrcies to for the training data and the test data

    #First we create two empty matrix (train  & test) with the same dimmesions.
    rawdata_train2, delme = train_test_split(rawdata_train, train_size=keep)
    rawdata=rawdata_train2
    M = np.zeros((ratings_full.user_id.max()+1,movies.new_movieId.max()+1))
    M[:,:] = np.nan


    # Now we populate the training matrix with training ratings
    rawdata = np.asanyarray(rawdata)
    for uid, mid, rating in rawdata:
        M[int(uid),int(mid)] = rating

    # We make use of masks to easily identify the cells with an actual rating
    MTF = ~np.isnan(M)
    M0 = np.nan_to_num(M)

    # Set Variables
    d = ds
    sigma = sigmas
    lam = lams

    #Initialize U and V
    U = np.random.randn(M.shape[0],d)
    V = np.random.randn(d,M.shape[1])
    
    omega = np.nan_to_num(np.divide(M,M))
    objective = np.array([])
    rmse_temp = np.array([])
    
    #
    start = timer()
    for n in range(iterations):
        #
    
        for i in range(M.shape[0]):

            mask = MTF[i,:]
            temp = V[:,mask].dot(V[:,mask].T)
            temp = lam*sigma*np.identity(len(temp)) + temp
            temp = np.linalg.inv(temp)
            temp = temp.dot(V[:,mask].dot(M[i,:][mask]))
            U[i] = temp
        #  
        for j in range(M.shape[1]):

            mask = MTF[:,j]
            temp = U.T[:,mask].dot(U.T[:,mask].T)
            temp = lam*sigma*np.identity(len(temp)) + temp
            temp = np.linalg.inv(temp)
            temp = temp.dot(U.T[:,mask].dot(M[:,j][mask]))
            V[:,j] = temp
        
    
        # Get all my predictions
        Mguess = U.dot(V)
        if (n)%10 ==0:
            print('Itereation: ',n , 'data size: ', keep)
    end = timer()
    duration = [(end-start)]
    durations.iloc[row] = [keep, duration[0]]


#####
durations
# Out:
# Itereation:  0 data size:  0.9
# Itereation:  10 data size:  0.9
# Itereation:  20 data size:  0.9
# Itereation:  30 data size:  0.9
# Itereation:  40 data size:  0.9
# Itereation:  0 data size:  0.8
# Itereation:  10 data size:  0.8
# Itereation:  20 data size:  0.8
# Itereation:  30 data size:  0.8
# Itereation:  40 data size:  0.8
# Itereation:  0 data size:  0.7
# Itereation:  10 data size:  0.7
# Itereation:  20 data size:  0.7
# Itereation:  30 data size:  0.7
# Itereation:  40 data size:  0.7
# Itereation:  0 data size:  0.6
# Itereation:  10 data size:  0.6
# Itereation:  20 data size:  0.6
# Itereation:  30 data size:  0.6
# Itereation:  40 data size:  0.6
# Itereation:  0 data size:  0.5
# Itereation:  10 data size:  0.5
# Itereation:  20 data size:  0.5
# Itereation:  30 data size:  0.5
# Itereation:  40 data size:  0.5
# Itereation:  0 data size:  0.4
# Itereation:  10 data size:  0.4
# Itereation:  20 data size:  0.4
# Itereation:  30 data size:  0.4
# Itereation:  40 data size:  0.4
# Itereation:  0 data size:  0.3
# Itereation:  10 data size:  0.3
# Itereation:  20 data size:  0.3
# Itereation:  30 data size:  0.3
# Itereation:  40 data size:  0.3
# Itereation:  0 data size:  0.2
# Itereation:  10 data size:  0.2
# Itereation:  20 data size:  0.2
# Itereation:  30 data size:  0.2
# Itereation:  40 data size:  0.2
# Itereation:  0 data size:  0.1
# Itereation:  10 data size:  0.1
# Itereation:  20 data size:  0.1
# Itereation:  30 data size:  0.1
# Itereation:  40 data size:  0.1
#    percent_of_data  Time in seconds
# 0              0.9        32.686034
# 1              0.8        30.674157
# 2              0.7        29.477333
# 3              0.6        31.125003
# 4              0.5        30.725515
# 5              0.4        28.936068
# 6              0.3        28.029807
# 7              0.2        28.114620
# 8              0.1        25.991562

# %%
plt.plot(durations.set_index('percent_of_data'))
plt.title('Time of execution vs Size of data (50 Iteration per run)')
plt.xlabel('Percent used from full data (full data set is 80003)')
plt.ylabel('Durarin in seconds')

print('The chart below shows the time for execution has high variability but it does not change drasticly. \n\
This is probably because all test contain the same amount of users, movies and rating matrix dimensions. \n\
An alternative way to test scaling could be to remove movies and or users from the data set.')
plt.show()
# Out:
# The chart below shows the time for execution has high variability but it does not change drasticly.
# This is probably because all test contain the same amount of users, movies and rating matrix dimensions.
# An alternative way to test scaling could be to remove movies and or users from the data set.

# %%
# We now create the appropriate matrcies to for the training data and the test data

#First we create two empty matrix (train  & test) with the same dimmesions.
rawdata=rawdata_train
M = np.zeros((ratings_full.user_id.max()+1,movies.new_movieId.max()+1))
M[:,:] = np.nan

Mtest = np.zeros((ratings_full.user_id.max()+1,movies.new_movieId.max()+1))
Mtest[:,:] = np.nan

# Now we populate the training matrix with training ratings
rawdata = np.asanyarray(rawdata)
for uid, mid, rating in rawdata:
    M[int(uid),int(mid)] = rating
    
# We make use of masks to easily identify the cells with an actual rating
MTF = ~np.isnan(M)
M0 = np.nan_to_num(M)

# Here we populate the test matrix with the test ratings
rawdata = rawdata_test
rawdata = np.asanyarray(rawdata)
for uid, mid, rating in rawdata:
    Mtest[int(uid),int(mid)] = rating

MtestTF = ~np.isnan(Mtest)

# %% [markdown]
# ### How many ratings do we have for each movie

# %%
# Show the number of ratings per movie
temp = MTF.sum(axis=0)
avg = temp.mean()
mid = np.median(temp)

plt.figure(figsize=(15,7))
#plt.plot(MTF.sum(axis=0))
plt.scatter(range(temp.shape[0]), MTF.sum(axis=0), marker='.')
plt.axhline(y=avg, color='r', label='MEAN: %i' %int(avg) )
plt.axhline(y=mid, color='y', label='MEDIAN: %i' %int(mid) )
plt.title('Number of users that rated the movie')
plt.xlabel('Movie ID (1-9125)')
plt.ylabel('Number of users that rated the movie')
plt.legend()
print(' \n', 'The chart below shows that most movies have less than 8 ratings')
plt.show()
# Out:
#
#  The chart below shows that most movies have less than 8 ratings

# %%
# We add this number to the movies matrix becuase they will provide a good idea of how much information we have about each movie.

temp = pd.DataFrame(MTF.sum(axis=0)).reset_index()
temp = movies.merge(temp, how='left', left_on='new_movieId', right_on='index')
temp = temp.rename(columns={0:'ratings_count'})
temp = temp.drop('index', axis=1)
movies = temp
movies.head()
# Out:
#    new_movieId  movieId                               title  ratings_count
# 0            1        1                    Toy Story (1995)            201
# 1            2        2                      Jumanji (1995)             85
# 2            3        3             Grumpier Old Men (1995)             48
# 3            4        4            Waiting to Exhale (1995)              8
# 4            5        5  Father of the Bride Part II (1995)             47

# %% [markdown]
# ### Parameter opimization and model execution

# %%
#%% Now we will run the movdel with different parameters and choose the one with the lowers RMSE
'''Best combination from SUPRISE:
Factors: 15 highest
Sigma: .05 lowest
Lambda .1
Epoch 100
MAE= .701
RMSE= .915
'''

ds= [10, 15] # The number of factors
sigmas = [.5, 1] # The learning rate
lams = [1, 5] # The regularization parameter

iterations = 50 # Number of epochs
rounds = (len(ds)*len(sigmas)*len(lams))

# %%
# This cell will run the model for each combination of the the parameters. It will also choose the model with the lowest RMSE.

# We create some tables to capture metadata about the model execution
objective_all = np.zeros((iterations,rounds))
rmse_all = np.zeros((iterations,rounds))
cols = ['round','factors','sigma','lambda','mae','rmse', 'objective']
rmse_obj = pd.DataFrame(np.zeros((rounds,len(cols))), columns= cols)
objective_best = 0
rmse_best=1000

# Now we run the model for all the parameter combinations
for r,combination in enumerate(itertools.product(ds, sigmas, lams)):
    d = combination[0]
    sigma = combination[1]
    lam = combination[2]

    #Initialize U and V
    U = np.random.randn(M.shape[0],d)
    V = np.random.randn(d,M.shape[1])
    #V = pd.read_csv('v_init_jc.csv',header= None)
    #V = np.asanyarray(V)
    
    omega = np.nan_to_num(np.divide(M,M))
    objective = np.array([])
    rmse_temp = np.array([])
    
    #
    for n in range(iterations):
        #
    
        for i in range(M.shape[0]):
            #temp = V.dot(omega[i]*np.identity(len(omega[i]))).dot(V.T)
            #
            mask = MTF[i,:]
            temp = V[:,mask].dot(V[:,mask].T)
            temp = lam*sigma*np.identity(len(temp)) + temp
            temp = np.linalg.inv(temp)
            #temp = temp.dot(V.dot(M0[i]))
            temp = temp.dot(V[:,mask].dot(M[i,:][mask]))
            U[i] = temp
        #  
        for j in range(M.shape[1]):
            #temp = U.T.dot(omega[:,j]*np.identity(len(omega[:,j]))).dot(U)
            mask = MTF[:,j]
            temp = U.T[:,mask].dot(U.T[:,mask].T)
            temp = lam*sigma*np.identity(len(temp)) + temp
            temp = np.linalg.inv(temp)
            #temp = temp.dot(U.T.dot(M0[:,j]))  # Are the indexs correct?
            temp = temp.dot(U.T[:,mask].dot(M[:,j][mask]))
            V[:,j] = temp
        #print(n, ':iteration  ', r, ':Round', d, ':d', sigma, 'sigma', lam, ':Lambda')
    
        # Get all my predictions
        Mguess = U.dot(V)
        
        # COLLECT OUTPUTS:  
        # Calculate my Objective function for each iteration
        #temp = omega * Mguess
        #temp = (1/(2*sigma)) * np.abs(M0 - temp)**2
        temp = (1/(2*sigma)) * np.linalg.norm(M[MTF] - Mguess[MTF])**2
        
        #temp = temp.sum()       
        temp = -temp - ((lam/2)*(np.linalg.norm(U)**2)) - ((lam/2)*(np.linalg.norm(V)**2)) 
        
        # Calculate my RMSE
 
        objective = np.append(objective, temp)
        
        # Calculate RMSE for each iteration
        temp2 = np.sqrt(((Mguess[MtestTF] - Mtest[MtestTF])**2).mean())
        rmse_temp = np.append(rmse_temp, temp2)
        
        print(n, ':iteration  ', r, ':Round', d, ':d', sigma, 'sigma', lam, ':Lambda', object)
        
    objective_all[:,r] = objective
    rmse_all[:,r] = rmse_temp
    # Save the best V

    if rmse_temp[-1]< rmse_best:
        rmse_best = rmse_temp[-1]
        V_final = V
        U_final = U
        Mguess_final = Mguess
        r_final = r
        print(r,' Best Round')
    print(r, ' :Round', rmse_temp[-1], ' :rmse', rmse_best, ' : best rmse')
    # Calculate the RMSE
    mae = (np.abs(Mguess[MtestTF] - Mtest[MtestTF]).sum())/MtestTF.sum()
    rmse = np.sqrt((((Mguess[MtestTF] - Mtest[MtestTF])**2).sum())/MtestTF.sum())
    rmse_obj.iloc[r] = [r, d, sigma, lam, mae, rmse, objective[-1]] #add temp to add the objective back in
# Out:
# 0 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 1 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 2 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 3 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 4 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 5 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 6 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 7 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 8 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 9 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 10 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 11 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 12 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 13 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 14 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 15 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 16 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 17 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 18 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 19 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 20 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 21 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 22 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 23 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 24 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 25 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 26 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 27 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 28 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 29 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 30 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 31 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 32 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 33 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 34 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 35 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 36 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 37 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 38 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 39 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 40 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 41 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 42 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 43 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 44 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 45 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 46 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 47 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 48 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 49 :iteration   0 :Round 10 :d 0.5 sigma 1 :Lambda
# 0  Best Round
# 0  :Round 1.49143505606  :rmse 1.49143505606  : best rmse
# 0 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 1 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 2 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 3 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 4 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 5 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 6 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 7 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 8 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 9 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 10 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 11 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 12 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 13 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 14 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 15 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 16 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 17 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 18 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 19 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 20 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 21 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 22 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 23 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 24 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 25 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 26 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 27 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 28 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 29 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 30 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 31 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 32 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 33 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 34 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 35 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 36 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 37 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 38 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 39 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 40 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 41 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 42 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 43 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 44 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 45 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 46 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 47 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 48 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 49 :iteration   1 :Round 10 :d 0.5 sigma 5 :Lambda
# 1  Best Round
# 1  :Round 1.28971186747  :rmse 1.28971186747  : best rmse
# 0 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 1 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 2 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 3 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 4 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 5 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 6 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 7 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 8 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 9 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 10 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 11 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 12 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 13 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 14 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 15 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 16 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 17 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 18 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 19 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 20 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 21 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 22 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 23 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 24 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 25 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 26 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 27 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 28 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 29 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 30 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 31 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 32 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 33 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 34 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 35 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 36 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 37 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 38 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 39 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 40 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 41 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 42 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 43 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 44 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 45 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 46 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 47 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 48 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 49 :iteration   2 :Round 10 :d 1 sigma 1 :Lambda
# 2  :Round 1.34686464396  :rmse 1.28971186747  : best rmse
# 0 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 1 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 2 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 3 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 4 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 5 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 6 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 7 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 8 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 9 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 10 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 11 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 12 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 13 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 14 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 15 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 16 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 17 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 18 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 19 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 20 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 21 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 22 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 23 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 24 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 25 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 26 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 27 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 28 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 29 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 30 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 31 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 32 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 33 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 34 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 35 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 36 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 37 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 38 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 39 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 40 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 41 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 42 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 43 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 44 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 45 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 46 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 47 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 48 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 49 :iteration   3 :Round 10 :d 1 sigma 5 :Lambda
# 3  Best Round
# 3  :Round 1.24387358442  :rmse 1.24387358442  : best rmse
# 0 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 1 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 2 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 3 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 4 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 5 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 6 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 7 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 8 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 9 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 10 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 11 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 12 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 13 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 14 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 15 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 16 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 17 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 18 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 19 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 20 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 21 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 22 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 23 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 24 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 25 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 26 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 27 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 28 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 29 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 30 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 31 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 32 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 33 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 34 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 35 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 36 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 37 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 38 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 39 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 40 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 41 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 42 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 43 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 44 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 45 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 46 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 47 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 48 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 49 :iteration   4 :Round 15 :d 0.5 sigma 1 :Lambda
# 4  :Round 1.56435851049  :rmse 1.24387358442  : best rmse
# 0 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 1 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 2 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 3 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 4 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 5 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 6 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 7 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 8 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 9 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 10 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 11 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 12 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 13 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 14 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 15 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 16 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 17 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 18 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 19 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 20 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 21 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 22 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 23 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 24 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 25 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 26 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 27 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 28 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 29 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 30 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 31 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 32 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 33 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 34 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 35 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 36 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 37 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 38 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 39 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 40 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 41 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 42 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 43 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 44 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 45 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 46 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 47 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 48 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 49 :iteration   5 :Round 15 :d 0.5 sigma 5 :Lambda
# 5  :Round 1.32047134715  :rmse 1.24387358442  : best rmse
# 0 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 1 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 2 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 3 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 4 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 5 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 6 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 7 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 8 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 9 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 10 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 11 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 12 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 13 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 14 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 15 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 16 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 17 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 18 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 19 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 20 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 21 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 22 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 23 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 24 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 25 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 26 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 27 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 28 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 29 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 30 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 31 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 32 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 33 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 34 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 35 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 36 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 37 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 38 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 39 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 40 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 41 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 42 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 43 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 44 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 45 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 46 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 47 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 48 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 49 :iteration   6 :Round 15 :d 1 sigma 1 :Lambda
# 6  :Round 1.44322407296  :rmse 1.24387358442  : best rmse
# 0 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 1 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 2 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 3 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 4 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 5 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 6 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 7 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 8 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 9 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 10 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 11 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 12 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 13 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 14 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 15 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 16 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 17 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 18 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 19 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 20 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 21 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 22 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 23 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 24 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 25 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 26 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 27 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 28 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 29 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 30 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 31 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 32 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 33 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 34 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 35 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 36 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 37 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 38 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 39 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 40 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 41 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 42 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 43 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 44 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 45 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 46 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 47 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 48 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 49 :iteration   7 :Round 15 :d 1 sigma 5 :Lambda
# 7  :Round 1.27420515491  :rmse 1.24387358442  : best rmse

# %%
print('This shows the rmse and the correlating parameter of each round')
print('Round:', r_final, ' was the one with the lowest RMSE and it will be the model used goin forward.')
rmse_obj
# Out:
# This shows the rmse and the correlating parameter of each round
# Round: 3  was the one with the lowest RMSE and it will be the model used goin forward.
#    round  factors  sigma  lambda       mae      rmse     objective
# 0    0.0     10.0    0.5     1.0  1.070843  1.491435 -30246.726817
# 1    1.0     10.0    0.5     5.0  0.931558  1.289712 -63377.467805
# 2    2.0     10.0    1.0     1.0  0.974968  1.346865 -19026.549029
# 3    3.0     10.0    1.0     5.0  0.901063  1.243874 -50240.649600
# 4    4.0     15.0    0.5     1.0  1.143849  1.564359 -23390.129019
# 5    5.0     15.0    0.5     5.0  0.966964  1.320471 -58017.684301
# 6    6.0     15.0    1.0     1.0  1.061924  1.443224 -16097.711135
# 7    7.0     15.0    1.0     5.0  0.928577  1.274205 -48335.796510

# %% [markdown]
# ### Model performance

# %%
#%%     Plot objective function
temp = pd.DataFrame(objective_all)
plt.figure(figsize=(12,12))
for i in range(rounds):
    #plt.scatter(range(1,100), objective_all[:,i], alpha= .5, s= 15, label= 'Round %i' %(i+1))
    plt.plot(objective_all[:,i], label= 'Round %i' %(i))
    plt.legend()
    plt.title('Objective Function for each rounds')
    plt.xlabel('Iteration')
    plt.ylabel('Objective Function Value')
print('The chart below shows the objective function calculated against the training data.\n\
It is interesting that the round with the best objective function is not the one with the lowest RMSE.\n\
This may be due to the fact that some combination of parameters result in overfitting')
plt.show()
# Out:
# The chart below shows the objective function calculated against the training data.
# It is interesting that the round with the best objective function is not the one with the lowest RMSE.
# This may be due to the fact that some combination of parameters result in overfitting

# %%
#%%     Plot RMSE for each round across each iteration
temp = pd.DataFrame(rmse_all)
plt.figure(figsize=(12,12))
for i in range(rounds):
    #plt.scatter(range(1,100), objective_all[:,i], alpha= .5, s= 15, label= 'Round %i' %(i+1))
    plt.plot(rmse_all[:,i], label= 'Round %i' %(i))
    plt.legend()
    plt.title('RMSE over  Rounds')
    plt.xlabel('Iteration')
    plt.ylabel('RMSE Value')
print('The plot below shows that performance for each combination of model parameters')
plt.show()
# Out:
# The plot below shows that performance for each combination of model parameters

# %% [markdown]
# ### Find the 10 closest movies using Vj
# First search a movie then select the movieId
# We will search Start Wars

# %%
#%% Find your movie
searchmovie = 'Star Wa'


mask = movies.title.str.contains(searchmovie,case=False)
movies[mask][['title','ratings_count','new_movieId']]
#Input new_movieId on cell below
# Out:
#                                                   title  ratings_count  \
# 232           Star Wars: Episode IV - A New Hope (1977)            234
# 953   Star Wars: Episode V - The Empire Strikes Back...            177
# 966   Star Wars: Episode VI - Return of the Jedi (1983)            178
# 2103   Star Wars: Episode I - The Phantom Menace (1999)            113
# 4103  Star Wars: Episode II - Attack of the Clones (...             66
# 6139  Star Wars: Episode III - Revenge of the Sith (...             47
# 7023                   Star Wars: The Clone Wars (2008)              3
# 7570  Empire of Dreams: The Story of the 'Star Wars'...              1
# 8783  Star Wars: Episode VII - The Force Awakens (2015)             26
#
#       new_movieId
# 232           233
# 953           954
# 966           967
# 2103         2104
# 4103         4104
# 6139         6140
# 7023         7024
# 7570         7571
# 8783         8784

# %%
# Enter your Newmovie ID
selectmovieId = 967


mask = movies.new_movieId == selectmovieId
selectmovie_act = movies[mask]['title'].values[0]

# %%
movie_dist = np.zeros((V.shape[1],1))
for i in range(V.shape[1]):
    movie_dist[i,0] = np.linalg.norm( V_final[:,selectmovieId] - V_final[:,i])
movie_dist_df = pd.DataFrame(movie_dist, columns= [selectmovie_act])
#movie_dist_df.head()
temp = movie_dist_df.sort_values(by= selectmovie_act).iloc[1:21,:].loc[:,selectmovie_act].reset_index()
temp = temp.merge(movies[['new_movieId','title']], how='left', left_on='index', right_on='new_movieId')
temp[[selectmovie_act,'title']]
# Out:
#     Star Wars: Episode VI - Return of the Jedi (1983)  \
# 0                                            0.441927
# 1                                            0.455841
# 2                                            0.478243
# 3                                            0.562239
# 4                                            0.587874
# 5                                            0.592627
# 6                                            0.639995
# 7                                            0.681027
# 8                                            0.683044
# 9                                            0.683485
# 10                                           0.687628
# 11                                           0.721431
# 12                                           0.735186
# 13                                           0.736631
# 14                                           0.765271
# 15                                           0.767662
# 16                                           0.768359
# 17                                           0.769520
# 18                                           0.773357
# 19                                           0.777024
#
#                                                 title
# 0   Star Wars: Episode V - The Empire Strikes Back...
# 1           Star Wars: Episode IV - A New Hope (1977)
# 2                             Dark Knight, The (2008)
# 3                      Godfather: Part II, The (1974)
# 4                                    Gladiator (2000)
# 5                                  Matrix, The (1999)
# 6                            Untouchables, The (1987)
# 7   Raiders of the Lost Ark (Indiana Jones and the...
# 8                     Star Trek: First Contact (1996)
# 9                                       Batman (1989)
# 10                          Back to the Future (1985)
# 11                   Hunt for Red October, The (1990)
# 12                         Saving Private Ryan (1998)
# 13                           Beverly Hills Cop (1984)
# 14                                  Goldfinger (1964)
# 15                                    Iron Man (2008)
# 16                           Last Samurai, The (2003)
# 17                                       X-Men (2000)
# 18                                      Avatar (2009)
# 19                          That Thing You Do! (1996)
